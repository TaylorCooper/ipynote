# %%
import pandas as pd  # Pandas dataframes very cool for data analysis stuff
import numpy as np  # Numpy is math functionality 

import pylab as pl
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.ticker as tkr
import time, csv, os

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
###
### Set run parameters and paths
###

# Run parameters
dataPath = "F:\\AFCC Metal FSU Testing 2014\\A3\\Accepted\\"
saveLoc = "F:\\AFCC Metal FSU Testing 2014\\A3\\Accepted\\"
setMMRPath = "F:\\AFCC Metal FSU Testing 2014\\A3\\Accepted\\setMinMaxRegions.csv"
mlPath = 'F:\\AFCC Metal FSU Testing 2014\\A3\\Accepted\\analysisLogTest_'

# %%
###
### General plots and analysis log
###

defaultRegions = False # Set to true when building setMMRPath

# Used to set adv / rec regions
df2 = pd.read_csv(setMMRPath, sep=',', header=0)

# Set logging file details
ts = str(time.time())[2:-3] # timestamp
mlPathFinal = mlPath + ts + '.csv'
masterLogFile = open(mlPathFinal, 'wb')
mlog = csv.writer(masterLogFile, delimiter=',',quoting=csv.QUOTE_NONE)
headers = [
          'Filename',
          'aMin(idx)',
          'aMax(idx)',
          'rMin(idx)',
          'rMax(idx)',
          'advTime_Mean(s)',
          'revTime_Mean(s)',
          'Dia_Init(mm)',
          'Dia_Max(mm)',
          # Left Side
          'lAdv_Mean(deg)',
          'lAdv_Std(deg)',
          'lRec_Mean(deg)',
          'lRec_Std(deg)',
          'lHyst_Mean(deg)',
          'lHyst_Std(deg)',
          # Right side
          'rAdv_Mean(deg)',
          'rAdv_Std(deg)',
          'rRec_Mean(deg)',
          'rRec_Std(deg)',
          'rHyst_Mean(deg)',
          'rHyst_Std(deg)',
          ]
mlog.writerow(headers)

# For loop that looks for all files ending in .txt in the file path above
for root, subFolders, files in os.walk(dataPath):
    
    for aFile in files:
        
        # Ignore stuff that's not a data csv
        if 'analysisLog' in aFile: continue
        if aFile[-9:] != '_data.csv': continue
            
        path = root + '\\' + aFile
        print "Analyzing: " + path
        
        # Get aMin aMax rMin rMax from setMMR\
        if defaultRegions:
            aMin = 50
            aMax = 145
            rMin = 245
            rMax = 270
        else:
            aMin = df2[aFile][0]
            aMax = df2[aFile][1]
            rMin = df2[aFile][2]
            rMax = df2[aFile][3]
            
        # Skip first row, header = first row after skip
        df = pd.read_csv(path, sep=',', skiprows=1, header=0)  

        # Calibrate data, this is slightly in accurate in our case
        pxToMM = lambda x: 0.31*x/23.5 # Convert bubble diameter to mm from px
        framesToSeconds = lambda x: x/30

        # Reference the columns of your matrices
        x = df['frameNumber'].apply(framesToSeconds)
        dia = df['diameter'].apply(pxToMM)
        lCA = df['leftCA']
        rCA = df['rightCA']

        # Get values 
        xAdv = x[aMin:aMax].mean()
        xRec = x[rMin:rMax].mean()
        dIni = dia[0]
        dMax = dia.max()
        
        # Left edge
        lAdv_Mean = lCA[aMin:aMax].mean()
        lAdv_Std = lCA[aMin:aMax].std()

        # Make sure you are not referencing outside the dataseries with all NaN values dropped
        # Also make sure the user has not told you to ignore receding by setting rMin=0
        if rMin != 0 and rMin < len(lCA.dropna()):
            rMaxL = rMax if rMax < len(lCA) else len(lCA) # Check you don't go out of bounds
            lRec_Mean = lCA[rMin:rMaxL].mean()
            lRec_Std = lCA[rMin:rMaxL].std()
            lHyst_Mean = lAdv_Mean - lRec_Mean
            lHyst_Std = np.sqrt(lAdv_Std**2 + lRec_Std**2)
        else:
            lRec_Mean = lRec_Std = lHyst_Mean = lHyst_Std = 'NaN'
        
        # Right edge
        rAdv_Mean = rCA[aMin:aMax].mean()
        rAdv_Std = rCA[aMin:aMax].std()
        if rMin != 0 and rMin < len(rCA.dropna()):
            rMaxR = rMax if rMax < len(rCA) else len(rCA)
            rRec_Mean = rCA[rMin:rMaxR].mean()
            rRec_Std = rCA[rMin:rMaxR].std()
            rHyst_Mean = rAdv_Mean - rRec_Mean
            rHyst_Std = np.sqrt(rAdv_Std**2 + rRec_Std**2)
        else:
            rRec_Mean = rRec_Std = rHyst_Mean = rHyst_Std = 'NaN'

        # Append data to log file
        row = [
              aFile,
              aMin,
              aMax,
              rMin,
              rMax,
              xAdv,
              xRec,
              dIni,
              dMax,
              lAdv_Mean,
              lAdv_Std,
              lRec_Mean,
              lRec_Std,
              lHyst_Mean,
              lHyst_Std,
              rAdv_Mean,
              rAdv_Std,
              rRec_Mean,
              rRec_Std,
              rHyst_Mean,
              rHyst_Std
          ]
        mlog.writerow(row)
        masterLogFile.flush() # Flush data incase of crash

        # Start making a plot
        fig = plt.figure()
        ax = fig.add_subplot(111)
        ax2 = ax.twinx()

        # Plot Simple Things
        ax.plot(x,lCA,'r.',markersize=2)
        ax.plot(x,rCA,'b.',markersize=2)
        ax2.plot(x, dia, 'g')
        ax.plot(xAdv,lAdv_Mean,'ro', alpha=0.75)
        ax.plot(xAdv,rAdv_Mean, 'bo', alpha=0.75)
        if rMin != 0:
            if rRec_Mean != 'NaN':
                ax.plot(xRec,rRec_Mean,'bo', alpha=0.75)
            if lRec_Mean != 'NaN':
                ax.plot(xRec,lRec_Mean,'ro', alpha=0.75)

        # Set labeles
        ax.set_ylabel('Contact Angle (deg)', size=8)
        ax.set_xlabel('Time (s)', size=8)
        name = aFile[:-9]
        name = name + '  Adv=' + str(int((lAdv_Mean+rAdv_Mean)/2))
        if rMin != 0:
            if rRec_Mean != 'NaN' and lRec_Mean != 'NaN
                name = name + '  Rec=' + str(int((lRec_Mean+rRec_Mean)/2))
                name = name + '  Hyst=' + str(int((lHyst_Mean+rHyst_Mean)/2))
        ax.set_title(name, size=8)
        ax2.set_ylabel('Diameter (mm)', size=8)

        # Scale axis and set ticks
        ax.axis([0,max(x)+10, 0,110])
        ax2.axis([0,max(x)+10, 0,18])
        ax.xaxis.set_major_locator(tkr.MultipleLocator(20))
        ax.yaxis.set_major_locator(tkr.MultipleLocator(10))
        ax2.yaxis.set_major_locator(tkr.MultipleLocator(2))

        # Plot angle calculation boundaries
        if 'CAS' not in name:
            ax.axvline(x[aMin]+1, color='k', ls='--', linewidth=0.65, alpha=0.5)
            ax.axvline(x[aMax], color='k', ls='--', linewidth=0.65, alpha=0.5)
        if rMin != 0:
            xMin = rMin if rMin < len(x) else len(x)-1
            xMax = rMax if rMax < len(x) else len(x)-1
            ax.axvline(x[xMin], color='k', ls='--', linewidth=0.65, alpha=0.5)
            ax.axvline(x[xMax], color='k', ls='--', linewidth=0.65, alpha=0.5)

        # Make legend
        p1 = plt.Rectangle((0, 0), 1, 1, fc='r')
        p2 = plt.Rectangle((0, 0), 1, 1, fc='b')
        p3 = plt.Rectangle((0, 0), 1, 1, fc='g')
        ax.legend([p1,p2,p3], ['Left CA','Right CA','Diameter'], 
               loc=1,prop={'size':8})

        # Save the output as a png
        savefig(saveLoc+aFile[:-9]+'.png', dpi=350, papertype='b10', orientation='portrait', bbox_inches='tight')
        show()
        clf()
        
        masterLogFile.flush()
            
masterLogFile.close()  # Close logfile so it can be read
# Out:
# Analyzing: F:\AFCC Metal FSU Testing 2014\A3\Accepted\AL01_B_accepted\20141218-13_04_34-CA3_DB_AL01_B-01_BED482\20141218-13_04_34-CA3_DB_AL01_B-01_data.csv
# Analyzing: F:\AFCC Metal FSU Testing 2014\A3\Accepted\AL01_B_accepted\20141218-13_07_42-CA3_DB_AL01_B-02_BED472\20141218-13_07_42-CA3_DB_AL01_B-02_data.csv
# Analyzing: F:\AFCC Metal FSU Testing 2014\A3\Accepted\AL01_B_accepted\20141218-13_11_01-CA3_DB_AL01_B-03_BED462\20141218-13_11_01-CA3_DB_AL01_B-03_data.csv
# Analyzing: F:\AFCC Metal FSU Testing 2014\A3\Accepted\AL01_B_accepted\20141218-13_14_30-CA3_DB_AL01_B-04_BED467\20141218-13_14_30-CA3_DB_AL01_B-04_data.csv
# Analyzing: F:\AFCC Metal FSU Testing 2014\A3\Accepted\AL01_B_accepted\20141218-13_17_53-CA3_DB_AL01_B-05_BED460\20141218-13_17_53-CA3_DB_AL01_B-05_data.csv
# Analyzing: F:\AFCC Metal FSU Testing 2014\A3\Accepted\AL01_B_accepted\20141218-13_33_30-CA3_DB_AL01_B-06_BED457\20141218-13_33_30-CA3_DB_AL01_B-06_data.csv
# Analyzing: F:\AFCC Metal FSU Testing 2014\A3\Accepted\AL01_B_accepted\20141218-13_40_15-CA3_DB_AL01_B-08_BED463\20141218-13_40_15-CA3_DB_AL01_B-08_data.csv
# Analyzing: F:\AFCC Metal FSU Testing 2014\A3\Accepted\AL01_B_accepted\20141218-13_43_33-CA3_DB_AL01_B-09_BED493\20141218-13_43_33-CA3_DB_AL01_B-09_data.csv
# Analyzing: F:\AFCC Metal FSU Testing 2014\A3\Accepted\AL01_B_accepted\20141218-13_49_28-CA3_DB_AL01_B-11_BED475\20141218-13_49_28-CA3_DB_AL01_B-11_data.csv
# Analyzing: F:\AFCC Metal FSU Testing 2014\A3\Accepted\AL01_C_accepted\20141218-16_00_05-CA3_DB_AL01_C-01_BED497\20141218-16_00_05-CA3_DB_AL01_C-01_data.csv
# Analyzing: F:\AFCC Metal FSU Testing 2014\A3\Accepted\AL01_C_accepted\20141218-16_03_20-CA3_DB_AL01_C-02_BED479\20141218-16_03_20-CA3_DB_AL01_C-02_data.csv
# Analyzing: F:\AFCC Metal FSU Testing 2014\A3\Accepted\AL01_C_accepted\20141218-16_06_23-CA3_DB_AL01_C-03_BED480\20141218-16_06_23-CA3_DB_AL01_C-03_data.csv
# Analyzing: F:\AFCC Metal FSU Testing 2014\A3\Accepted\AL01_C_accepted\20141218-16_24_41-CA3_DB_AL01_C-06_BED472\20141218-16_24_41-CA3_DB_AL01_C-06_data.csv
# Analyzing: F:\AFCC Metal FSU Testing 2014\A3\Accepted\AL01_C_accepted\20141218-16_37_37-CA3_DB_AL01_C-09_BED474\20141218-16_37_37-CA3_DB_AL01_C-09_data.csv
# Analyzing: F:\AFCC Metal FSU Testing 2014\A3\Accepted\AL01_C_accepted\20141218-16_40_41-CA3_DB_AL01_C-10_BED466\20141218-16_40_41-CA3_DB_AL01_C-10_data.csv
# Analyzing: F:\AFCC Metal FSU Testing 2014\A3\Accepted\AL01_C_accepted\20141218-16_43_43-CA3_DB_AL01_C-11_BED469\20141218-16_43_43-CA3_DB_AL01_C-11_data.csv
# Analyzing: F:\AFCC Metal FSU Testing 2014\A3\Accepted\BORIT_accepted\20141217-16_45_30-CA3_DB_B002_A-01_BED407\20141217-16_45_30-CA3_DB_B002_A-01_data.csv
# Analyzing: F:\AFCC Metal FSU Testing 2014\A3\Accepted\BORIT_accepted\20141217-17_30_44-CA3_DB_B002_A-04_BED416\20141217-17_30_44-CA3_DB_B002_A-04_data.csv
# Analyzing: F:\AFCC Metal FSU Testing 2014\A3\Accepted\BORIT_accepted\20141217-17_33_23-CA3_DB_B002_A-05_BED420\20141217-17_33_23-CA3_DB_B002_A-05_data.csv
# Analyzing: F:\AFCC Metal FSU Testing 2014\A3\Accepted\BORIT_accepted\20141217-17_36_44-CA3_DB_B002_A-06_BED418\20141217-17_36_44-CA3_DB_B002_A-06_data.csv
# Analyzing: F:\AFCC Metal FSU Testing 2014\A3\Accepted\BORIT_accepted\20141217-17_39_41-CA3_DB_B002_A-07_BED416\20141217-17_39_41-CA3_DB_B002_A-07_data.csv
# Analyzing: F:\AFCC Metal FSU Testing 2014\A3\Accepted\BORIT_accepted\20141217-18_38_36-CA3_DB_B002_A-11_BED511\20141217-18_38_36-CA3_DB_B002_A-11_data.csv
# Analyzing: F:\AFCC Metal FSU Testing 2014\A3\Accepted\BORIT_accepted\20141217-18_50_01-CA3_DB_B002_A-14_BED503\20141217-18_50_01-CA3_DB_B002_A-14_data.csv
# Analyzing: F:\AFCC Metal FSU Testing 2014\A3\Accepted\BORIT_accepted\20141217-19_00_34-CA3_DB_B002_A-15_BED517\20141217-19_00_34-CA3_DB_B002_A-15_data.csv
# Analyzing: F:\AFCC Metal FSU Testing 2014\A3\Accepted\BORIT_accepted\20141217-19_03_13-CA3_DB_B002_A-16_BED500\20141217-19_03_13-CA3_DB_B002_A-16_data.csv
# Analyzing: F:\AFCC Metal FSU Testing 2014\A3\Accepted\BORIT_accepted\20141217-20_00_00-CA3_DB_B002_A-17_BED507\20141217-20_00_00-CA3_DB_B002_A-17_data.csv
# Analyzing: F:\AFCC Metal FSU Testing 2014\A3\Accepted\BORIT_accepted\20141217-20_00_00-CA3_DB_B002_A-19_BED497\20141217-20_00_00-CA3_DB_B002_A-19_data.csv
# Analyzing: F:\AFCC Metal FSU Testing 2014\A3\Accepted\PC01_A_accepted\20141218-22_41_33-CA3_DB_PC01_A-01_BED580\20141218-22_41_33-CA3_DB_PC01_A-01_data.csv
# Analyzing: F:\AFCC Metal FSU Testing 2014\A3\Accepted\PC01_A_accepted\20141218-22_46_34-CA3_DB_PC01_A-03_BED605\20141218-22_46_34-CA3_DB_PC01_A-03_data.csv
# Analyzing: F:\AFCC Metal FSU Testing 2014\A3\Accepted\PC01_A_accepted\20141218-22_48_53-CA3_DB_PC01_A-04_BED617\20141218-22_48_53-CA3_DB_PC01_A-04_data.csv
# Analyzing: F:\AFCC Metal FSU Testing 2014\A3\Accepted\PC01_A_accepted\20141218-22_51_21-CA3_DB_PC01_A-05_BED617\20141218-22_51_21-CA3_DB_PC01_A-05_data.csv
# Analyzing: F:\AFCC Metal FSU Testing 2014\A3\Accepted\PC01_A_accepted\20141218-23_01_40-CA3_DB_PC01_A-07_BED601\20141218-23_01_40-CA3_DB_PC01_A-07_data.csv
# Analyzing: F:\AFCC Metal FSU Testing 2014\A3\Accepted\PC01_A_accepted\20141218-23_08_00-CA3_DB_PC01_A-09_BED597\20141218-23_08_00-CA3_DB_PC01_A-09_data.csv
# Analyzing: F:\AFCC Metal FSU Testing 2014\A3\Accepted\PC01_A_accepted\20141218-23_10_50-CA3_DB_PC01_A-10_BED619\20141218-23_10_50-CA3_DB_PC01_A-10_data.csv
# Analyzing: F:\AFCC Metal FSU Testing 2014\A3\Accepted\PC01_A_accepted\20141218-23_13_56-CA3_DB_PC01_A-11_BED603\20141218-23_13_56-CA3_DB_PC01_A-11_data.csv
# Analyzing: F:\AFCC Metal FSU Testing 2014\A3\Accepted\PC01_B_accepted\20141221-22_40_07-CA3_DB_PC01_B-01_BED508\20141221-22_40_07-CA3_DB_PC01_B-01_data.csv
# Analyzing: F:\AFCC Metal FSU Testing 2014\A3\Accepted\PC01_B_accepted\20141221-22_44_26-CA3_DB_PC01_B-02_BED489\20141221-22_44_26-CA3_DB_PC01_B-02_data.csv
# Analyzing: F:\AFCC Metal FSU Testing 2014\A3\Accepted\PC01_B_accepted\20141221-22_48_21-CA3_DB_PC01_B-03_BED490\20141221-22_48_21-CA3_DB_PC01_B-03_data.csv
# Analyzing: F:\AFCC Metal FSU Testing 2014\A3\Accepted\PC01_B_accepted\20141221-22_52_34-CA3_DB_PC01_B-04_BED496\20141221-22_52_34-CA3_DB_PC01_B-04_data.csv
# Analyzing: F:\AFCC Metal FSU Testing 2014\A3\Accepted\PC01_B_accepted\20141221-22_57_11-CA3_DB_PC01_B-05_BED468\20141221-22_57_11-CA3_DB_PC01_B-05_data.csv
# Analyzing: F:\AFCC Metal FSU Testing 2014\A3\Accepted\PC01_B_accepted\20141221-23_11_04-CA3_DB_PC01_B-06_BED454\20141221-23_11_04-CA3_DB_PC01_B-06_data.csv
# Analyzing: F:\AFCC Metal FSU Testing 2014\A3\Accepted\PC01_B_accepted\20141221-23_15_08-CA3_DB_PC01_B-07_BED466\20141221-23_15_08-CA3_DB_PC01_B-07_data.csv
# Analyzing: F:\AFCC Metal FSU Testing 2014\A3\Accepted\PC01_B_accepted\20141221-23_19_13-CA3_DB_PC01_B-08_BED456\20141221-23_19_13-CA3_DB_PC01_B-08_data.csv
# Analyzing: F:\AFCC Metal FSU Testing 2014\A3\Accepted\PC01_B_accepted\20141221-23_23_10-CA3_DB_PC01_B-09_BED461\20141221-23_23_10-CA3_DB_PC01_B-09_data.csv
# Analyzing: F:\AFCC Metal FSU Testing 2014\A3\Accepted\PC01_B_accepted\20141221-23_26_55-CA3_DB_PC01_B-10_BED455\20141221-23_26_55-CA3_DB_PC01_B-10_data.csv
# Analyzing: F:\AFCC Metal FSU Testing 2014\A3\Accepted\PC01_C_accepted\20141221-23_49_29-CA3_DB_PC01_C-02_BED494\20141221-23_49_29-CA3_DB_PC01_C-02_data.csv
# Analyzing: F:\AFCC Metal FSU Testing 2014\A3\Accepted\PC01_C_accepted\20141221-23_53_29-CA3_DB_PC01_C-03_BED451\20141221-23_53_29-CA3_DB_PC01_C-03_data.csv
# Analyzing: F:\AFCC Metal FSU Testing 2014\A3\Accepted\PC01_C_accepted\20141221-23_57_13-CA3_DB_PC01_C-04_BED471\20141221-23_57_13-CA3_DB_PC01_C-04_data.csv
# Analyzing: F:\AFCC Metal FSU Testing 2014\A3\Accepted\PC01_C_accepted\20141222-00_01_08-CA3_DB_PC01_C-05_BED463\20141222-00_01_08-CA3_DB_PC01_C-05_data.csv
# Analyzing: F:\AFCC Metal FSU Testing 2014\A3\Accepted\PC01_C_accepted\20141222-00_04_54-CA3_DB_PC01_C-06_BED458\20141222-00_04_54-CA3_DB_PC01_C-06_data.csv
# Analyzing: F:\AFCC Metal FSU Testing 2014\A3\Accepted\PC01_C_accepted\20141222-00_19_19-CA3_DB_PC01_C-07_BED479\20141222-00_19_19-CA3_DB_PC01_C-07_data.csv
# Analyzing: F:\AFCC Metal FSU Testing 2014\A3\Accepted\PC01_C_accepted\20141222-00_24_25-CA3_DB_PC01_C-08_BED464\20141222-00_24_25-CA3_DB_PC01_C-08_data.csv
# Analyzing: F:\AFCC Metal FSU Testing 2014\A3\Accepted\PC01_C_accepted\20141222-00_28_21-CA3_DB_PC01_C-09_BED466\20141222-00_28_21-CA3_DB_PC01_C-09_data.csv
# Analyzing: F:\AFCC Metal FSU Testing 2014\A3\Accepted\PC01_C_accepted\20141222-00_32_19-CA3_DB_PC01_C-10_BED453\20141222-00_32_19-CA3_DB_PC01_C-10_data.csv
# Analyzing: F:\AFCC Metal FSU Testing 2014\A3\Accepted\PC01_C_accepted\20141222-00_36_57-CA3_DB_PC01_C-11_BED473\20141222-00_36_57-CA3_DB_PC01_C-11_data.csv
# Analyzing: F:\AFCC Metal FSU Testing 2014\A3\Accepted\PMMA01_A_accepted\20141218-21_53_21-CA3_DB_PMMA01_A-01_BED592\20141218-21_53_21-CA3_DB_PMMA01_A-01_data.csv
# Analyzing: F:\AFCC Metal FSU Testing 2014\A3\Accepted\PMMA01_A_accepted\20141218-21_56_10-CA3_DB_PMMA01_A-02_BED610\20141218-21_56_10-CA3_DB_PMMA01_A-02_data.csv
# Analyzing: F:\AFCC Metal FSU Testing 2014\A3\Accepted\PMMA01_A_accepted\20141218-22_02_00-CA3_DB_PMMA01_A-04_BED588\20141218-22_02_00-CA3_DB_PMMA01_A-04_data.csv
# Analyzing: F:\AFCC Metal FSU Testing 2014\A3\Accepted\PMMA01_A_accepted\20141218-22_04_14-CA3_DB_PMMA01_A-05_BED575\20141218-22_04_14-CA3_DB_PMMA01_A-05_data.csv
# Analyzing: F:\AFCC Metal FSU Testing 2014\A3\Accepted\PMMA01_A_accepted\20141218-22_06_47-CA3_DB_PMMA01_A-06_BED595\20141218-22_06_47-CA3_DB_PMMA01_A-06_data.csv
# Analyzing: F:\AFCC Metal FSU Testing 2014\A3\Accepted\PMMA01_A_accepted\20141218-22_20_01-CA3_DB_PMMA01_A-08_BED608\20141218-22_20_01-CA3_DB_PMMA01_A-08_data.csv
# Analyzing: F:\AFCC Metal FSU Testing 2014\A3\Accepted\PMMA01_A_accepted\20141218-22_22_32-CA3_DB_PMMA01_A-09_BED626\20141218-22_22_32-CA3_DB_PMMA01_A-09_data.csv
# Analyzing: F:\AFCC Metal FSU Testing 2014\A3\Accepted\PMMA01_A_accepted\20141218-22_25_07-CA3_DB_PMMA01_A-10_BED607\20141218-22_25_07-CA3_DB_PMMA01_A-10_data.csv
# Analyzing: F:\AFCC Metal FSU Testing 2014\A3\Accepted\PMMA01_A_accepted\20141218-22_27_47-CA3_DB_PMMA01_A-11_BED578\20141218-22_27_47-CA3_DB_PMMA01_A-11_data.csv
# Analyzing: F:\AFCC Metal FSU Testing 2014\A3\Accepted\PMMA01_B_accepted\20141221-19_35_27-CA3_DB_PMMA01_B-05_BED486\20141221-19_35_27-CA3_DB_PMMA01_B-05_data.csv
# Analyzing: F:\AFCC Metal FSU Testing 2014\A3\Accepted\PMMA01_B_accepted\20141221-19_39_13-CA3_DB_PMMA01_B-06_BED510\20141221-19_39_13-CA3_DB_PMMA01_B-06_data.csv
# Analyzing: F:\AFCC Metal FSU Testing 2014\A3\Accepted\PMMA01_B_accepted\20141221-19_43_44-CA3_DB_PMMA01_B-07_BED511\20141221-19_43_44-CA3_DB_PMMA01_B-07_data.csv
# Analyzing: F:\AFCC Metal FSU Testing 2014\A3\Accepted\PMMA01_B_accepted\20141221-19_47_57-CA3_DB_PMMA01_B-08_BED510\20141221-19_47_57-CA3_DB_PMMA01_B-08_data.csv
# Analyzing: F:\AFCC Metal FSU Testing 2014\A3\Accepted\PMMA01_B_accepted\20141221-19_51_52-CA3_DB_PMMA01_B-09_BED503\20141221-19_51_52-CA3_DB_PMMA01_B-09_data.csv
# Analyzing: F:\AFCC Metal FSU Testing 2014\A3\Accepted\PMMA01_B_accepted\20141221-20_10_53-CA3_DB_PMMA01_B-10_BED524\20141221-20_10_53-CA3_DB_PMMA01_B-10_data.csv
# Analyzing: F:\AFCC Metal FSU Testing 2014\A3\Accepted\PMMA01_B_accepted\20141221-21_17_16-CA3_DB_PMMA01_B-11_BED540\20141221-21_17_16-CA3_DB_PMMA01_B-11_data.csv
# Analyzing: F:\AFCC Metal FSU Testing 2014\A3\Accepted\PMMA01_B_accepted\20141221-21_21_09-CA3_DB_PMMA01_B-12_BED500\20141221-21_21_09-CA3_DB_PMMA01_B-12_data.csv
# Analyzing: F:\AFCC Metal FSU Testing 2014\A3\Accepted\PMMA01_C_accepted\20141221-21_40_36-CA3_DB_PMMA01_C-01_BED503\20141221-21_40_36-CA3_DB_PMMA01_C-01_data.csv
# Analyzing: F:\AFCC Metal FSU Testing 2014\A3\Accepted\PMMA01_C_accepted\20141221-21_44_35-CA3_DB_PMMA01_C-02_BED504\20141221-21_44_35-CA3_DB_PMMA01_C-02_data.csv
# Analyzing: F:\AFCC Metal FSU Testing 2014\A3\Accepted\PMMA01_C_accepted\20141221-21_48_59-CA3_DB_PMMA01_C-03_BED497\20141221-21_48_59-CA3_DB_PMMA01_C-03_data.csv
# Analyzing: F:\AFCC Metal FSU Testing 2014\A3\Accepted\PMMA01_C_accepted\20141221-21_57_43-CA3_DB_PMMA01_C-05_BED527\20141221-21_57_43-CA3_DB_PMMA01_C-05_data.csv
# Analyzing: F:\AFCC Metal FSU Testing 2014\A3\Accepted\PMMA01_C_accepted\20141221-22_11_02-CA3_DB_PMMA01_C-06_BED501\20141221-22_11_02-CA3_DB_PMMA01_C-06_data.csv
# Analyzing: F:\AFCC Metal FSU Testing 2014\A3\Accepted\PMMA01_C_accepted\20141221-22_15_15-CA3_DB_PMMA01_C-07_BED505\20141221-22_15_15-CA3_DB_PMMA01_C-07_data.csv
# Analyzing: F:\AFCC Metal FSU Testing 2014\A3\Accepted\PMMA01_C_accepted\20141221-22_19_32-CA3_DB_PMMA01_C-08_BED505\20141221-22_19_32-CA3_DB_PMMA01_C-08_data.csv
# Analyzing: F:\AFCC Metal FSU Testing 2014\A3\Accepted\PMMA01_C_accepted\20141221-22_23_33-CA3_DB_PMMA01_C-09_BED491\20141221-22_23_33-CA3_DB_PMMA01_C-09_data.csv
# Analyzing: F:\AFCC Metal FSU Testing 2014\A3\Accepted\SS01_A_accepted\20141218-17_11_06-CA3_DB_SS01_A-01_BED468\20141218-17_11_06-CA3_DB_SS01_A-01_data.csv
# Analyzing: F:\AFCC Metal FSU Testing 2014\A3\Accepted\SS01_A_accepted\20141218-17_17_36-CA3_DB_SS01_A-03_BED466\20141218-17_17_36-CA3_DB_SS01_A-03_data.csv
# Analyzing: F:\AFCC Metal FSU Testing 2014\A3\Accepted\SS01_A_accepted\20141218-17_21_07-CA3_DB_SS01_A-04_BED468\20141218-17_21_07-CA3_DB_SS01_A-04_data.csv
# Analyzing: F:\AFCC Metal FSU Testing 2014\A3\Accepted\SS01_A_accepted\20141218-17_24_24-CA3_DB_SS01_A-05_BED483\20141218-17_24_24-CA3_DB_SS01_A-05_data.csv
# Analyzing: F:\AFCC Metal FSU Testing 2014\A3\Accepted\SS01_A_accepted\20141218-17_54_24-CA3_DB_SS01_A-06_BED473\20141218-17_54_24-CA3_DB_SS01_A-06_data.csv
# Analyzing: F:\AFCC Metal FSU Testing 2014\A3\Accepted\SS01_A_accepted\20141218-17_57_42-CA3_DB_SS01_A-07_BED457\20141218-17_57_42-CA3_DB_SS01_A-07_data.csv
# Analyzing: F:\AFCC Metal FSU Testing 2014\A3\Accepted\SS01_A_accepted\20141218-18_00_51-CA3_DB_SS01_A-08_BED472\20141218-18_00_51-CA3_DB_SS01_A-08_data.csv
# Analyzing: F:\AFCC Metal FSU Testing 2014\A3\Accepted\SS01_A_accepted\20141218-18_07_12-CA3_DB_SS01_A-10_BED462\20141218-18_07_12-CA3_DB_SS01_A-10_data.csv
# Analyzing: F:\AFCC Metal FSU Testing 2014\A3\Accepted\SS01_B_accepted\20141218-19_05_20-CA3_DB_SS01_B-01_BED486\20141218-19_05_20-CA3_DB_SS01_B-01_data.csv
# Analyzing: F:\AFCC Metal FSU Testing 2014\A3\Accepted\SS01_B_accepted\20141218-19_09_01-CA3_DB_SS01_B-02_BED482\20141218-19_09_01-CA3_DB_SS01_B-02_data.csv
# Analyzing: F:\AFCC Metal FSU Testing 2014\A3\Accepted\SS01_B_accepted\20141218-19_25_04-CA3_DB_SS01_B-07_BED474\20141218-19_25_04-CA3_DB_SS01_B-07_data.csv
# Analyzing: F:\AFCC Metal FSU Testing 2014\A3\Accepted\SS01_B_accepted\20141218-20_01_03-CA3_DB_SS01_B-08_BED470\20141218-20_01_03-CA3_DB_SS01_B-08_data.csv
# Analyzing: F:\AFCC Metal FSU Testing 2014\A3\Accepted\SS01_B_accepted\20141218-20_07_57-CA3_DB_SS01_B-10_BED474\20141218-20_07_57-CA3_DB_SS01_B-10_data.csv
# Analyzing: F:\AFCC Metal FSU Testing 2014\A3\Accepted\SS01_B_accepted\20141218-20_11_03-CA3_DB_SS01_B-11_BED480\20141218-20_11_03-CA3_DB_SS01_B-11_data.csv
# Analyzing: F:\AFCC Metal FSU Testing 2014\A3\Accepted\SS01_C_accepted\20141218-20_23_23-CA3_DB_SS01_C-01_BED451\20141218-20_23_23-CA3_DB_SS01_C-01_data.csv
# Analyzing: F:\AFCC Metal FSU Testing 2014\A3\Accepted\SS01_C_accepted\20141218-20_27_08-CA3_DB_SS01_C-02_BED461\20141218-20_27_08-CA3_DB_SS01_C-02_data.csv
# Analyzing: F:\AFCC Metal FSU Testing 2014\A3\Accepted\SS01_C_accepted\20141218-20_31_36-CA3_DB_SS01_C-03_BED444\20141218-20_31_36-CA3_DB_SS01_C-03_data.csv
# Analyzing: F:\AFCC Metal FSU Testing 2014\A3\Accepted\SS01_C_accepted\20141218-20_39_46-CA3_DB_SS01_C-04_BED462\20141218-20_39_46-CA3_DB_SS01_C-04_data.csv
# Analyzing: F:\AFCC Metal FSU Testing 2014\A3\Accepted\SS01_C_accepted\20141218-20_45_38-CA3_DB_SS01_C-06_BED441\20141218-20_45_38-CA3_DB_SS01_C-06_data.csv
# Analyzing: F:\AFCC Metal FSU Testing 2014\A3\Accepted\SS01_C_accepted\20141218-20_49_06-CA3_DB_SS01_C-07_BED448\20141218-20_49_06-CA3_DB_SS01_C-07_data.csv
# Analyzing: F:\AFCC Metal FSU Testing 2014\A3\Accepted\SS01_C_accepted\20141218-21_01_59-CA3_DB_SS01_C-09_BED474\20141218-21_01_59-CA3_DB_SS01_C-09_data.csv
