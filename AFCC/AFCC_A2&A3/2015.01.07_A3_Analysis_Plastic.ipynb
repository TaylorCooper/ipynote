# %%
###
###  2014.01.07
###  ANALYSIS of 68 videos total
###  F:\AFCC Metal FSU Testing 2014\A3\Plastic\R_0.8
###  Final protocol for data analysis - softer filtering - final all
###

import sys
sys.path.insert(0, 'D:\\GitHub\\workspace\\A2_ContactAngle\\')
import main # getContactAngle main

headersVid = [
          'Filename',
          'FolderID',
          'FabID',
          'Sample#',
          'Region',
          'AdvCALeft(deg)',
          'AdvCARight(deg)',
          'MaxDiameter(px)',
          'BED(px)'       
          ]

varsDebugVid = {
    'PATH' : 'F:\\AFCC Metal FSU Testing 2014\\A3\\Plastic\\R_0.8\\',
    'VSF' : 100, # Video start frame
    'VEF' : 30000, # Video end frame (max frame)
    'N' : 10, # Analyze every Nth frame
    'R' : 0.8, # Rotation in degrees
    'ROI' : (100,800,10,1910), # Rowmin, Rowmax, Colmin,Colmax
    'MASK' : (10,1890,255), # Colmin, colmax
    'BR' : 120, # Brightness increase (255 = white)
    'TH' : 160, # Binary threshold
    'POLYDEG' : 2,  # Degree of polyfit
    'DERIVOFF' : 5, # Contact angle measurement offset from BED, in pixel/10
    'MINSYGPOS' : 400, # Minimum syringe position in pixels from left side
    'SYGOFF' : 18, # Offset from syringe for measureing vertically
    'VIDMID' : 100, # BED selection point
    'BUBMAX' : 900, # Maximum bubble width
    'MINFITPTS' : 5, # Minimum dataset size to attempt analysis
    'MAXFITPTS' : 35, # Maximum points for fit attempt, prevents garbage pts.
    'DPI' : 100, # Plot dots per inch, ignored for .svg
    'PLOTXOFF' : 1000, # Graph offset from image center in X direction 
    'PLOTYOFF' : 120, # Graph offset from image center in Y+ direction
    'DEBUG' : True, # Plots and saves images
    'RESETBED' : False, # Will ignore _BED if present
    'ASSIGNBEDS' : False, # Will ignore analysis and assign beds, responds to RESETBED
    'REMOVEBEDS' : False, # Will ignore assignBeds and analysis and remove _BED
}

gCA1 = main.getContactAngle(varsDebugVid, headersVid)
gCA1.analyzeVideos()

# %%
###
###  2014.01.07
###  ANALYSIS of 68 videos total
###  F:\AFCC Metal FSU Testing 2014\A3\Plastic\R_1.35
###  Final protocol for data analysis - softer filtering - final all
###

import sys
sys.path.insert(0, 'D:\\GitHub\\workspace\\A2_ContactAngle\\')
import main # getContactAngle main

headersVid = [
          'Filename',
          'FolderID',
          'FabID',
          'Sample#',
          'Region',
          'AdvCALeft(deg)',
          'AdvCARight(deg)',
          'MaxDiameter(px)',
          'BED(px)'       
          ]

varsDebugVid = {
    'PATH' : 'F:\\AFCC Metal FSU Testing 2014\\A3\\Plastic\\R_1.35\\',
    'VSF' : 100, # Video start frame
    'VEF' : 30000, # Video end frame (max frame)
    'N' : 10, # Analyze every Nth frame
    'R' : 1.35, # Rotation in degrees
    'ROI' : (100,800,10,1910), # Rowmin, Rowmax, Colmin,Colmax
    'MASK' : (10,1890,255), # Colmin, colmax
    'BR' : 120, # Brightness increase (255 = white)
    'TH' : 160, # Binary threshold
    'POLYDEG' : 2,  # Degree of polyfit
    'DERIVOFF' : 5, # Contact angle measurement offset from BED, in pixel/10
    'MINSYGPOS' : 400, # Minimum syringe position in pixels from left side
    'SYGOFF' : 18, # Offset from syringe for measureing vertically
    'VIDMID' : 100, # BED selection point
    'BUBMAX' : 900, # Maximum bubble width
    'MINFITPTS' : 5, # Minimum dataset size to attempt analysis
    'MAXFITPTS' : 35, # Maximum points for fit attempt, prevents garbage pts.
    'DPI' : 100, # Plot dots per inch, ignored for .svg
    'PLOTXOFF' : 1000, # Graph offset from image center in X direction 
    'PLOTYOFF' : 120, # Graph offset from image center in Y+ direction
    'DEBUG' : True, # Plots and saves images
    'RESETBED' : False, # Will ignore _BED if present
    'ASSIGNBEDS' : False, # Will ignore analysis and assign beds, responds to RESETBED
    'REMOVEBEDS' : False, # Will ignore assignBeds and analysis and remove _BED
}

gCA1 = main.getContactAngle(varsDebugVid, headersVid)
gCA1.analyzeVideos()

# %%
###
###  2014.01.07
###  ANALYSIS of 68 videos total
###  F:\AFCC Metal FSU Testing 2014\A3\Plastic\R_1.35\PMMA01_B_rejected
###  Increased brightness
###  Final protocol for data analysis - softer filtering - final all
###

import sys
sys.path.insert(0, 'D:\\GitHub\\workspace\\A2_ContactAngle\\')
import main # getContactAngle main

headersVid = [
          'Filename',
          'FolderID',
          'FabID',
          'Sample#',
          'Region',
          'AdvCALeft(deg)',
          'AdvCARight(deg)',
          'MaxDiameter(px)',
          'BED(px)'       
          ]

varsDebugVid = {
    'PATH' : 'F:\\AFCC Metal FSU Testing 2014\\A3\\Plastic\\R_1.35\\PMMA01_B_rejected\\',
    'VSF' : 100, # Video start frame
    'VEF' : 30000, # Video end frame (max frame)
    'N' : 10, # Analyze every Nth frame
    'R' : 1.55, # Rotation in degrees
    'ROI' : (100,800,10,1910), # Rowmin, Rowmax, Colmin,Colmax
    'MASK' : (10,1890,255), # Colmin, colmax
    'BR' : 140, # Brightness increase (255 = white)
    'TH' : 160, # Binary threshold
    'POLYDEG' : 2,  # Degree of polyfit
    'DERIVOFF' : 5, # Contact angle measurement offset from BED, in pixel/10
    'MINSYGPOS' : 400, # Minimum syringe position in pixels from left side
    'SYGOFF' : 18, # Offset from syringe for measureing vertically
    'VIDMID' : 100, # BED selection point
    'BUBMAX' : 900, # Maximum bubble width
    'MINFITPTS' : 5, # Minimum dataset size to attempt analysis
    'MAXFITPTS' : 35, # Maximum points for fit attempt, prevents garbage pts.
    'DPI' : 100, # Plot dots per inch, ignored for .svg
    'PLOTXOFF' : 1000, # Graph offset from image center in X direction 
    'PLOTYOFF' : 120, # Graph offset from image center in Y+ direction
    'DEBUG' : True, # Plots and saves images
    'RESETBED' : False, # Will ignore _BED if present
    'ASSIGNBEDS' : False, # Will ignore analysis and assign beds, responds to RESETBED
    'REMOVEBEDS' : False, # Will ignore assignBeds and analysis and remove _BED
}

gCA1 = main.getContactAngle(varsDebugVid, headersVid)
gCA1.analyzeVideos()

# %%
###
###  2014.01.07
###  ANALYSIS of 68 videos total
###  F:\AFCC Metal FSU Testing 2014\A3\Plastic\R_1.35\PMMA01_B_rejected
###  Increased brightness
###  Final protocol for data analysis - softer filtering - final all
###

import sys
sys.path.insert(0, 'D:\\GitHub\\workspace\\A2_ContactAngle\\')
import main # getContactAngle main

headersVid = [
          'Filename',
          'FolderID',
          'FabID',
          'Sample#',
          'Region',
          'AdvCALeft(deg)',
          'AdvCARight(deg)',
          'MaxDiameter(px)',
          'BED(px)'       
          ]

varsDebugVid = {
    'PATH' : 'F:\\AFCC Metal FSU Testing 2014\\A3\\Plastic\\R_1.35\\PMMA01_B_rejected\\',
    'VSF' : 100, # Video start frame
    'VEF' : 30000, # Video end frame (max frame)
    'N' : 10, # Analyze every Nth frame
    'R' : 1.5, # Rotation in degrees
    'ROI' : (100,800,10,1910), # Rowmin, Rowmax, Colmin,Colmax
    'MASK' : (10,1890,255), # Colmin, colmax
    'BR' : 140, # Brightness increase (255 = white)
    'TH' : 160, # Binary threshold
    'POLYDEG' : 2,  # Degree of polyfit
    'DERIVOFF' : 5, # Contact angle measurement offset from BED, in pixel/10
    'MINSYGPOS' : 400, # Minimum syringe position in pixels from left side
    'SYGOFF' : 18, # Offset from syringe for measureing vertically
    'VIDMID' : 100, # BED selection point
    'BUBMAX' : 900, # Maximum bubble width
    'MINFITPTS' : 5, # Minimum dataset size to attempt analysis
    'MAXFITPTS' : 35, # Maximum points for fit attempt, prevents garbage pts.
    'DPI' : 100, # Plot dots per inch, ignored for .svg
    'PLOTXOFF' : 1000, # Graph offset from image center in X direction 
    'PLOTYOFF' : 120, # Graph offset from image center in Y+ direction
    'DEBUG' : True, # Plots and saves images
    'RESETBED' : False, # Will ignore _BED if present
    'ASSIGNBEDS' : False, # Will ignore analysis and assign beds, responds to RESETBED
    'REMOVEBEDS' : False, # Will ignore assignBeds and analysis and remove _BED
}

gCA1 = main.getContactAngle(varsDebugVid, headersVid)
gCA1.analyzeVideos()

# %%
###
###  2014.01.07
###  ANALYSIS of 68 videos total
###  F:\AFCC Metal FSU Testing 2014\A3\Plastic\R_1.35\PMMA01_B_rejected
###  Increased brightness
###  Final protocol for data analysis - softer filtering - final all
###

import sys
sys.path.insert(0, 'D:\\GitHub\\workspace\\A2_ContactAngle\\')
import main # getContactAngle main

headersVid = [
          'Filename',
          'FolderID',
          'FabID',
          'Sample#',
          'Region',
          'AdvCALeft(deg)',
          'AdvCARight(deg)',
          'MaxDiameter(px)',
          'BED(px)'       
          ]

varsDebugVid = {
    'PATH' : 'F:\\AFCC Metal FSU Testing 2014\\A3\\Plastic\\R_1.35\\PMMA01_C_borderline\\',
    'VSF' : 100, # Video start frame
    'VEF' : 30000, # Video end frame (max frame)
    'N' : 10, # Analyze every Nth frame
    'R' : 1.5, # Rotation in degrees
    'ROI' : (100,800,10,1910), # Rowmin, Rowmax, Colmin,Colmax
    'MASK' : (10,1890,255), # Colmin, colmax
    'BR' : 140, # Brightness increase (255 = white)
    'TH' : 160, # Binary threshold
    'POLYDEG' : 2,  # Degree of polyfit
    'DERIVOFF' : 5, # Contact angle measurement offset from BED, in pixel/10
    'MINSYGPOS' : 400, # Minimum syringe position in pixels from left side
    'SYGOFF' : 18, # Offset from syringe for measureing vertically
    'VIDMID' : 100, # BED selection point
    'BUBMAX' : 900, # Maximum bubble width
    'MINFITPTS' : 5, # Minimum dataset size to attempt analysis
    'MAXFITPTS' : 35, # Maximum points for fit attempt, prevents garbage pts.
    'DPI' : 100, # Plot dots per inch, ignored for .svg
    'PLOTXOFF' : 1000, # Graph offset from image center in X direction 
    'PLOTYOFF' : 120, # Graph offset from image center in Y+ direction
    'DEBUG' : True, # Plots and saves images
    'RESETBED' : False, # Will ignore _BED if present
    'ASSIGNBEDS' : False, # Will ignore analysis and assign beds, responds to RESETBED
    'REMOVEBEDS' : False, # Will ignore assignBeds and analysis and remove _BED
}

gCA1 = main.getContactAngle(varsDebugVid, headersVid)
gCA1.analyzeVideos()

# %%
###
###  2014.01.07
###  ANALYSIS of 68 videos total
###  Increased bed and tilt slightly
###  Final protocol for data analysis - softer filtering - final all
###

import sys
sys.path.insert(0, 'D:\\GitHub\\workspace\\A2_ContactAngle\\')
import main # getContactAngle main

headersVid = [
          'Filename',
          'FolderID',
          'FabID',
          'Sample#',
          'Region',
          'AdvCALeft(deg)',
          'AdvCARight(deg)',
          'MaxDiameter(px)',
          'BED(px)'       
          ]

varsDebugVid = {
    'PATH' : 'F:\\AFCC Metal FSU Testing 2014\\A3\\Plastic\\R_0.8\\PC01_B_accepted\\temp\\',
    'VSF' : 100, # Video start frame
    'VEF' : 30000, # Video end frame (max frame)
    'N' : 10, # Analyze every Nth frame
    'R' : 0.9, # Rotation in degrees
    'ROI' : (100,800,10,1910), # Rowmin, Rowmax, Colmin,Colmax
    'MASK' : (10,1890,255), # Colmin, colmax
    'BR' : 120, # Brightness increase (255 = white)
    'TH' : 160, # Binary threshold
    'POLYDEG' : 2,  # Degree of polyfit
    'DERIVOFF' : 5, # Contact angle measurement offset from BED, in pixel/10
    'MINSYGPOS' : 400, # Minimum syringe position in pixels from left side
    'SYGOFF' : 18, # Offset from syringe for measureing vertically
    'VIDMID' : 100, # BED selection point
    'BUBMAX' : 900, # Maximum bubble width
    'MINFITPTS' : 5, # Minimum dataset size to attempt analysis
    'MAXFITPTS' : 35, # Maximum points for fit attempt, prevents garbage pts.
    'DPI' : 100, # Plot dots per inch, ignored for .svg
    'PLOTXOFF' : 1000, # Graph offset from image center in X direction 
    'PLOTYOFF' : 120, # Graph offset from image center in Y+ direction
    'DEBUG' : True, # Plots and saves images
    'RESETBED' : False, # Will ignore _BED if present
    'ASSIGNBEDS' : False, # Will ignore analysis and assign beds, responds to RESETBED
    'REMOVEBEDS' : False, # Will ignore assignBeds and analysis and remove _BED
}

gCA1 = main.getContactAngle(varsDebugVid, headersVid)
gCA1.analyzeVideos()

# %%
###
###  2014.01.07
###  ANALYSIS of 68 videos total
###  Increased bed and tilt slightly
###  Final protocol for data analysis - softer filtering - final all
###

import sys
sys.path.insert(0, 'D:\\GitHub\\workspace\\A2_ContactAngle\\')
import main # getContactAngle main

headersVid = [
          'Filename',
          'FolderID',
          'FabID',
          'Sample#',
          'Region',
          'AdvCALeft(deg)',
          'AdvCARight(deg)',
          'MaxDiameter(px)',
          'BED(px)'       
          ]

varsDebugVid = {
    'PATH' : 'F:\\AFCC Metal FSU Testing 2014\\A3\\Plastic\\R_0.8\\PC01_B_accepted\\else\\',
    'VSF' : 100, # Video start frame
    'VEF' : 30000, # Video end frame (max frame)
    'N' : 10, # Analyze every Nth frame
    'R' : 0.9, # Rotation in degrees
    'ROI' : (100,800,10,1910), # Rowmin, Rowmax, Colmin,Colmax
    'MASK' : (10,1890,255), # Colmin, colmax
    'BR' : 120, # Brightness increase (255 = white)
    'TH' : 160, # Binary threshold
    'POLYDEG' : 2,  # Degree of polyfit
    'DERIVOFF' : 5, # Contact angle measurement offset from BED, in pixel/10
    'MINSYGPOS' : 400, # Minimum syringe position in pixels from left side
    'SYGOFF' : 18, # Offset from syringe for measureing vertically
    'VIDMID' : 100, # BED selection point
    'BUBMAX' : 900, # Maximum bubble width
    'MINFITPTS' : 5, # Minimum dataset size to attempt analysis
    'MAXFITPTS' : 35, # Maximum points for fit attempt, prevents garbage pts.
    'DPI' : 100, # Plot dots per inch, ignored for .svg
    'PLOTXOFF' : 1000, # Graph offset from image center in X direction 
    'PLOTYOFF' : 120, # Graph offset from image center in Y+ direction
    'DEBUG' : True, # Plots and saves images
    'RESETBED' : False, # Will ignore _BED if present
    'ASSIGNBEDS' : False, # Will ignore analysis and assign beds, responds to RESETBED
    'REMOVEBEDS' : False, # Will ignore assignBeds and analysis and remove _BED
}

gCA1 = main.getContactAngle(varsDebugVid, headersVid)
gCA1.analyzeVideos()

# %%
###
###  2014.01.07
###  ANALYSIS of 68 videos total
###  Increased bed and tilt slightly
###  Final protocol for data analysis - softer filtering - final all
###

import sys
sys.path.insert(0, 'D:\\GitHub\\workspace\\A2_ContactAngle\\')
import main # getContactAngle main

headersVid = [
          'Filename',
          'FolderID',
          'FabID',
          'Sample#',
          'Region',
          'AdvCALeft(deg)',
          'AdvCARight(deg)',
          'MaxDiameter(px)',
          'BED(px)'       
          ]

varsDebugVid = {
    'PATH' : 'F:\\AFCC Metal FSU Testing 2014\\A3\\Plastic\\R_0.8\\PC01_B_borderline\\',
    'VSF' : 100, # Video start frame
    'VEF' : 30000, # Video end frame (max frame)
    'N' : 10, # Analyze every Nth frame
    'R' : 0.9, # Rotation in degrees
    'ROI' : (100,800,10,1910), # Rowmin, Rowmax, Colmin,Colmax
    'MASK' : (10,1890,255), # Colmin, colmax
    'BR' : 120, # Brightness increase (255 = white)
    'TH' : 160, # Binary threshold
    'POLYDEG' : 2,  # Degree of polyfit
    'DERIVOFF' : 5, # Contact angle measurement offset from BED, in pixel/10
    'MINSYGPOS' : 400, # Minimum syringe position in pixels from left side
    'SYGOFF' : 18, # Offset from syringe for measureing vertically
    'VIDMID' : 100, # BED selection point
    'BUBMAX' : 900, # Maximum bubble width
    'MINFITPTS' : 5, # Minimum dataset size to attempt analysis
    'MAXFITPTS' : 35, # Maximum points for fit attempt, prevents garbage pts.
    'DPI' : 100, # Plot dots per inch, ignored for .svg
    'PLOTXOFF' : 1000, # Graph offset from image center in X direction 
    'PLOTYOFF' : 120, # Graph offset from image center in Y+ direction
    'DEBUG' : True, # Plots and saves images
    'RESETBED' : False, # Will ignore _BED if present
    'ASSIGNBEDS' : False, # Will ignore analysis and assign beds, responds to RESETBED
    'REMOVEBEDS' : False, # Will ignore assignBeds and analysis and remove _BED
}

gCA1 = main.getContactAngle(varsDebugVid, headersVid)
gCA1.analyzeVideos()
