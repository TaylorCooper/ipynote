# %%
import pandas as pd
import numpy as np
# %pylab inline

path = 'C:\\Users\\tcooper\\Desktop\\SS Scoda Design\\S4+ Issues\\08_Hotspot Run Failure Analysis\\'
datalogPath = path + "02_Output and Analysis\\2014.07.03 Run Log V3.1.csv"
df = pd.read_csv(datalogPath, sep=',')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
### Assignment for which dataframe is being plotted
# Dataframe for all
print 'All:', len(df['Protocol'])
name = 'WtMarker_BoxPlot_All' 

bp = df.boxplot(column='maxWt/Qnt', by='Wt mkr behavior', grid=False)
xticks(rotation=70)
bp.set_ylabel('maxWt/Qnt', size=8)
bp.set_xlabel('Wt mkr behavior', size=8)
bp.set_title('', size=11)
bp.set_ylim([0,6])

itemsX = []
for i in df['Wt mkr behavior']:
    if i not in itemsX:
        itemsX.append(i)
        
itemsX.sort()
print itemsX
               
for i,entry in enumerate(itemsX):
    y = df[df['Wt mkr behavior']==entry]['maxWt/Qnt']
    print entry, len(y)
    # Add some random "jitter" to the x-axis
    x = np.random.normal(i+1, 0.04, size=len(y))
    plot(x, y, 'r.', alpha=0.5)
    scatter(i+1, y.mean(), zorder=10000)

l = Line2D([0,10],[1,1],color='k',linestyle='--')                                    
bp.add_line(l)    
    
savefig(name, dpi=350, papertype='b10', orientation='portrait', bbox_inches='tight')#, format='pdf')
show()
# Out:
# All: 433
# ['Clean', 'WtBoomer', 'WtMajor', 'WtTrace']
# Clean 296
# WtBoomer 38
# WtMajor 46
# WtTrace 53

# %%
### Assignment for which dataframe is being plotted

df2 = df[df['Protocol'] == 'Hotspot v1.5.2 local.sp']
df3 = df[df['Protocol'] == 'OnTarget Protocol HotSpot v1.5.2.sp']
df4 = pd.concat([df2,df3])
print 'New Protocol:', len(df4['Protocol'])
name = 'WtMarker_BoxPlot_NewProtocol'


bp = df4.boxplot(column='maxWt/Qnt', by='Wt mkr behavior', grid=False)
xticks(rotation=70)
bp.set_ylabel('maxWt/Qnt', size=8)
bp.set_xlabel('Wt mkr behavior', size=8)
bp.set_title('', size=11)
bp.set_ylim([0,6])

itemsX = []
for i in df4['Wt mkr behavior']:
    if i not in itemsX:
        itemsX.append(i)
        
itemsX.sort()
print itemsX
               
for i,entry in enumerate(itemsX):
    y = df4[df4['Wt mkr behavior']==entry]['maxWt/Qnt']
    print entry, len(y)
    # Add some random "jitter" to the x-axis
    x = np.random.normal(i+1, 0.04, size=len(y))
    plot(x, y, 'r.', alpha=0.5)
    scatter(i+1, y.mean(), zorder=10000)

l = Line2D([0,10],[1,1],color='k',linestyle='--')                                    
bp.add_line(l)    
    
savefig(name, dpi=350, papertype='b10', orientation='portrait', bbox_inches='tight')#, format='pdf')
show()
# Out:
# New Protocol: 92
# ['Clean', 'WtBoomer', 'WtMajor', 'WtTrace']
# Clean 58
# WtBoomer 2
# WtMajor 16
# WtTrace 16

# %%
### Assignment for which dataframe is being plotted

# Dataframe for old protocols
df5 = df[df['Protocol'] != 'Hotspot v1.5.2 local.sp']
df6 = df5[df5['Protocol'] != 'OnTarget Protocol HotSpot v1.5.2.sp']
print 'Old Protocol:', len(df6['Protocol'])
name = 'WtMarker_BoxPlot_OldProtocol'

bp = df6.boxplot(column='maxWt/Qnt', by='Wt mkr behavior', grid=False)
xticks(rotation=70)
bp.set_ylabel('maxWt/Qnt', size=8)
bp.set_xlabel('Wt mkr behavior', size=8)
bp.set_title('', size=11)
bp.set_ylim([0,6])

itemsX = []
for i in df6['Wt mkr behavior']:
    if i not in itemsX:
        itemsX.append(i)
        
itemsX.sort()
print itemsX
               
for i,entry in enumerate(itemsX):
    y = df6[df6['Wt mkr behavior']==entry]['maxWt/Qnt']
    print entry, len(y)
    # Add some random "jitter" to the x-axis
    x = np.random.normal(i+1, 0.04, size=len(y))
    plot(x, y, 'r.', alpha=0.5)
    scatter(i+1, y.mean(), zorder=10000)

l = Line2D([0,10],[1,1],color='k',linestyle='--')                                    
bp.add_line(l)    
    
savefig(name, dpi=350, papertype='b10', orientation='portrait', bbox_inches='tight')#, format='pdf')
show()
# Out:
# Old Protocol: 341
# ['Clean', 'WtBoomer', 'WtMajor', 'WtTrace']
# Clean 238
# WtBoomer 36
# WtMajor 30
# WtTrace 37

# %%
### Assignment for which dataframe is being plotted


# Dataframe for old protocol less forking, botedge, bleed through
df7 = df6[df6['TopEdge'] == 0]
df7 = df7[df7['BotEdge'] == 0]
df7 = df7[df7['Bleedthrough'] == 0]
df7 = df7[df7['Fork'] == 0]
print 'Old Protocol No forking:', len(df7['Protocol'])
name = 'WtMarker_BoxPlot_OldProtocolLessForking'

bp = df7.boxplot(column='maxWt/Qnt', by='Wt mkr behavior', grid=False)
xticks(rotation=70)
bp.set_ylabel('maxWt/Qnt', size=8)
bp.set_xlabel('Wt mkr behavior', size=8)
bp.set_title('', size=11)
bp.set_ylim([0,6])

itemsX = []
for i in df7['Wt mkr behavior']:
    if i not in itemsX:
        itemsX.append(i)
        
itemsX.sort()
print itemsX
               
for i,entry in enumerate(itemsX):
    y = df7[df7['Wt mkr behavior']==entry]['maxWt/Qnt']
    print entry, len(y)
    # Add some random "jitter" to the x-axis
    x = np.random.normal(i+1, 0.04, size=len(y))
    plot(x, y, 'r.', alpha=0.5)
    scatter(i+1, y.mean(), zorder=10000)

l = Line2D([0,10],[1,1],color='k',linestyle='--')                                    
bp.add_line(l)    
    
savefig(name, dpi=350, papertype='b10', orientation='portrait', bbox_inches='tight')#, format='pdf')
show()
# Out:
# Old Protocol No forking: 36
# ['Clean', 'WtBoomer', 'WtMajor', 'WtTrace']
# Clean 26
# WtBoomer 1
# WtMajor 3
# WtTrace 6
