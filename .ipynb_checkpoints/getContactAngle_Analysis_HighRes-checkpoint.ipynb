# %%
###
###  Initial debug video with syringe pump and macro lens
###

import sys
sys.path.insert(0, 'D:\\GitHub\\workspace\\A2_ContactAngle\\')
import main # getContactAngle main

headersVid = [
          'Filename',
          'FolderID',
          'FabID',
          'Sample#',
          'Region',
          'AdvCALeft(deg)',
          'AdvCARight(deg)',
          'MaxDiameter(px)',
          'BED(px)'       
          ]

varsDebugVid = {
    # Always provide the trailing \\ for 'PATH' if it's a filepath
    'PATH' : 'D:\\Dropbox\\Clients\\AFCC\\Projects\\Metal FSU\\A2 - Material Characterization\\TEST DATA\\DEBUG\\',
    'VSF' : 100,
    'VEF' : 30000, # Set high for CA7
    'N' : 30, # Normally 30
    'R' : 3,
    'ROI' : (300,900,200,1800), # Rowmin, Rowmax, Colmin,Colmax
    'MASK' : (100,1400,255), # Colmin, colmax
    'BR' : 120,
    'TH' : 150,
    'POLYDEG' : 5,  ### Something wrong going on here
    'DERIVOFF' : 10,
    'MINSYGPOS' : 50,
    'SYGOFF' : 30, # Normally 6 but image res has gone up
    'VIDMID' : 1000, # Mid point of video to find BED
    'BUBMAX' : 1600,
    'MINFITPTS' : 12,
    'DPI' : 100, # plot quality (lower = faster
    'PLOTXOFF' : 700, # Graph offsets from image center 
    'PLOTYOFF' : 120, # Graph offsets
    'DEBUG' : True, # Plots and saves images
    'RESETBED' : True, # Will ignore _BED if present
    'ASSIGNBEDS' : False, # Will ignore analysis and assign beds, responds to RESETBED
    'REMOVEBEDS' : False, # Will ignore assignBeds and analysis and remove _BED
}

gCA1 = main.getContactAngle(varsDebugVid, headersVid)
gCA1.analyzeVideos()

# %%
###
###  2nd debug run
###

import sys
sys.path.insert(0, 'D:\\GitHub\\workspace\\A2_ContactAngle\\')
import main # getContactAngle main

headersVid = [
          'Filename',
          'FolderID',
          'FabID',
          'Sample#',
          'Region',
          'AdvCALeft(deg)',
          'AdvCARight(deg)',
          'MaxDiameter(px)',
          'BED(px)'       
          ]

varsDebugVid = {
    # Always provide the trailing \\ for 'PATH' if it's a filepath
    'PATH' : 'D:\\Dropbox\\Clients\\AFCC\\Projects\\Metal FSU\\A2 - Material Characterization\\TEST DATA\\DEBUG\\R0\\',
    'VSF' : 100,
    'VEF' : 30000, # Set high for CA7
    'N' : 1, # Normally 30
    'R' : 0,
    'ROI' : (300,900,200,1800), # Rowmin, Rowmax, Colmin,Colmax
    'MASK' : (100,1400,255), # Colmin, colmax
    'BR' : 120,
    'TH' : 150,
    'POLYDEG' : 10,  ### Something wrong going on here
    'DERIVOFF' : 5, # Was 10
    'MINSYGPOS' : 50,
    'SYGOFF' : 10, # For correctly rotated images
    'VIDMID' : 3000, # BED selection point
    'BUBMAX' : 1600,
    'MINFITPTS' : 20,
    'DPI' : 100, # plot quality (lower = faster
    'PLOTXOFF' : 700, # Graph offsets from image center 
    'PLOTYOFF' : 120, # Graph offsets
    'DEBUG' : True, # Plots and saves images
    'RESETBED' : False, # Will ignore _BED if present
    'ASSIGNBEDS' : False, # Will ignore analysis and assign beds, responds to RESETBED
    'REMOVEBEDS' : False, # Will ignore assignBeds and analysis and remove _BED
}

gCA1 = main.getContactAngle(varsDebugVid, headersVid)
gCA1.analyzeVideos()

# %%
###
###  Final protocol for data analysis
###

import sys
sys.path.insert(0, 'D:\\GitHub\\workspace\\A2_ContactAngle\\')
import main # getContactAngle main

headersVid = [
          'Filename',
          'FolderID',
          'FabID',
          'Sample#',
          'Region',
          'AdvCALeft(deg)',
          'AdvCARight(deg)',
          'MaxDiameter(px)',
          'BED(px)'       
          ]

varsDebugVid = {
    # Always provide the trailing \\ for 'PATH' if it's a filepath
    'PATH' : 'G:\\',
    'VSF' : 100,
    'VEF' : 30000, # Set high for CA7
    'N' : 30, # Normally 30
    'R' : 1,
    'ROI' : (100,900,200,1800), # Rowmin, Rowmax, Colmin,Colmax
    'MASK' : (100,1400,255), # Colmin, colmax
    'BR' : 120,
    'TH' : 150,
    'POLYDEG' : 10,  ### Something wrong going on here
    'DERIVOFF' : 10, # Was 10
    'MINSYGPOS' : 50,
    'SYGOFF' : 30, # For correctly rotated images
    'VIDMID' : 200, # BED selection point
    'BUBMAX' : 600,
    'MINFITPTS' : 20,
    'DPI' : 100, # plot quality (lower = faster
    'PLOTXOFF' : 700, # Graph offsets from image center 
    'PLOTYOFF' : 120, # Graph offsets
    'DEBUG' : True, # Plots and saves images
    'RESETBED' : False, # Will ignore _BED if present
    'ASSIGNBEDS' : False, # Will ignore analysis and assign beds, responds to RESETBED
    'REMOVEBEDS' : False, # Will ignore assignBeds and analysis and remove _BED
}

gCA1 = main.getContactAngle(varsDebugVid, headersVid)
gCA1.analyzeVideos()

# %%
###
###  Final protocol for data analysis - softer filtering - final all
###

import sys
sys.path.insert(0, 'D:\\GitHub\\workspace\\A2_ContactAngle\\')
import main # getContactAngle main

headersVid = [
          'Filename',
          'FolderID',
          'FabID',
          'Sample#',
          'Region',
          'AdvCALeft(deg)',
          'AdvCARight(deg)',
          'MaxDiameter(px)',
          'BED(px)'       
          ]

varsDebugVid = {
    'PATH' : 'D:\\_Work\\0000-AFCC_MetalFSU_A2\\2014.08.28_Analysis\\3DS\\',
    'VSF' : 100, # Video start frame
    'VEF' : 30000, # Video end frame (max frame)
    'N' : 15, # Analyze every Nth frame
    'R' : 1, # Rotation in degrees
    'ROI' : (100,800,10,1910), # Rowmin, Rowmax, Colmin,Colmax
    'MASK' : (10,1890,255), # Colmin, colmax
    'BR' : 90, # Brightness increase (255 = white)
    'TH' : 160, # Binary threshold
    'POLYDEG' : 10,  # Degree of polyfit
    'DERIVOFF' : 10, # Contact angle measurement offset from BED
    'MINSYGPOS' : 50, # Minimum syringe position in pixels from left side
    'SYGOFF' : 30, # Offset from syringe for measureing vertically
    'VIDMID' : 100, # BED selection point
    'BUBMAX' : 900, # Maximum bubble width
    'MINFITPTS' : 20, # Minimum dataset size to attempt analysis
    'DPI' : 100, # Plot dots per inch, ignored for .svg
    'PLOTXOFF' : 700, # Graph offset from image center in X direction 
    'PLOTYOFF' : 120, # Graph offset from image center in Y+ direction
    'DEBUG' : True, # Plots and saves images
    'RESETBED' : False, # Will ignore _BED if present
    'ASSIGNBEDS' : False, # Will ignore analysis and assign beds, responds to RESETBED
    'REMOVEBEDS' : False, # Will ignore assignBeds and analysis and remove _BED
}

gCA1 = main.getContactAngle(varsDebugVid, headersVid)
gCA1.analyzeVideos()

# %%
###
###  RUBY standard analysis
###

import sys
sys.path.insert(0, 'D:\\GitHub\\workspace\\A2_ContactAngle\\')
import main # getContactAngle main

headersVid = [
          'Filename',
          'FolderID',
          'FabID',
          'Sample#',
          'Region',
          'AdvCALeft(deg)',
          'AdvCARight(deg)',
          'MaxDiameter(px)',
          'BED(px)'       
          ]

varsDebugVid = {
    # Always provide the trailing \\ for 'PATH' if it's a filepath
    'PATH' : 'D:\\_Work\\0000-AFCC_MetalFSU_A2\\2014.08.28_Analysis\\RUBY\\',
    'VSF' : 1, # Start for video
    'VEF' : 30000, # Cut off for video
    'N' : 2,
    'R' : 1,
    'ROI' : (600,1050,10,1710), # Rowmin, Rowmax, Colmin,Colmax
    'MASK' : (10,1690,255), # Colmin, colmax
    'BR' : 90,
    'TH' : 160,
    'POLYDEG' : 10,  ### Something wrong going on here
    'DERIVOFF' : 2, # Was 10
    'MINSYGPOS' : 50,
    'SYGOFF' : 20, # For correctly rotated images
    'VIDMID' : 1, # BED selection point
    'BUBMAX' : 900, # May want to remove this parameter...?
    'MINFITPTS' : 10,
    'DPI' : 100, # plot quality (lower = faster), doesn't matter because svgs
    'PLOTXOFF' : 700, # Graph offsets from image center 
    'PLOTYOFF' : 120, # Graph offsets
    'DEBUG' : True, # Plots and saves images
    'RESETBED' : False, # Will ignore _BED if present
    'ASSIGNBEDS' : False, # Will ignore analysis and assign beds, responds to RESETBED
    'REMOVEBEDS' : False, # Will ignore assignBeds and analysis and remove _BED
}

gCA1 = main.getContactAngle(varsDebugVid, headersVid)
gCA1.analyzeVideos()
